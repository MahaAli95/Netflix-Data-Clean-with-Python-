# %%
import pandas as pd
import numpy as np

# %%
df_org = pd.read_csv(r'C:\Users\Syeda\Desktop\Data Analytics\Python Portfolio\Netflix\netflix_titles.csv')
df_org.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_opt = df_org.copy()
df_opt.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
df_opt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
del_col = ['show_id','description']
df_opt.drop(del_col, inplace=True, axis=1)
df_opt.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water              NaN
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans              NaN
# 4  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# ...

# %%
cal_null = df_opt.isnull().sum()
print(cal_null)
# Out:
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# dtype: int64

# %%
df_opt['director'] = df_opt['director'].fillna('Unknown')

# %%
df_opt['rating'] = df_opt['rating'].fillna('Unknown')

# %%
df_opt['duration'] = df_opt['duration'].fillna('Unknown')

# %%
df_opt['country'] = df_opt['country'].fillna('Unknown')

# %%
df_opt['cast'] = df_opt['cast'].fillna('Unknown')

# %%
df_opt['title'] = df_opt['title'].fillna('Unknown')

# %%
#df_opt['date_added'].fillna('22.02.2021', inplace=True)

# %%
type_val = df_opt['type'].value_counts()

# %%
director_val = df_opt['director'].value_counts()

# %%
duration_val = df_opt['duration'].value_counts()

# %%
country_val = df_opt['country'].value_counts()

# %%
cast_val = df_opt['cast'].value_counts()

# %%
date_val = df_opt['date_added'].value_counts()

# %%
release_val = df_opt['release_year'].value_counts()

# %%
rating_val = df_opt['rating'].value_counts()

# %%
listed_val = df_opt['listed_in'].value_counts()

# %%
df_opt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   object
#  1   title         8807 non-null   object
#  2   director      8807 non-null   object
#  3   cast          8807 non-null   object
#  4   country       8807 non-null   object
#  5   date_added    8797 non-null   object
#  6   release_year  8807 non-null   int64
#  7   rating        8807 non-null   object
#  8   duration      8807 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 688.2+ KB

# %%
df_opt = df_opt.astype({'type':'category'})

# %%
df_opt["date_added"] =  pd.to_datetime(df_opt["date_added"])

# %%
df_opt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8807 non-null   category
#  1   title         8807 non-null   object
#  2   director      8807 non-null   object
#  3   cast          8807 non-null   object
#  4   country       8807 non-null   object
#  5   date_added    8797 non-null   datetime64[ns]
#  6   release_year  8807 non-null   int64
#  7   rating        8807 non-null   object
#  8   duration      8807 non-null   object
#  9   listed_in     8807 non-null   object
# dtypes: category(1), datetime64[ns](1), int64(1), object(7)
# memory usage: 628.1+ KB

# %%
#df_opt = df_opt.replace(np.nan, 'Unkown', inplace=True)

# %%
df_opt=df_opt.dropna(subset=['date_added','rating']) #to drop nan values of date and rating

# %%
df_opt.head()
# Out:
#       type                  title         director  \
# 0    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1  TV Show          Blood & Water          Unknown
# 2  TV Show              Ganglands  Julien Leclercq
# 3  TV Show  Jailbirds New Orleans          Unknown
# 4  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                            Unknown  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                            Unknown        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
df_opt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8797 entries, 0 to 8806
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   type          8797 non-null   category
#  1   title         8797 non-null   object
#  2   director      8797 non-null   object
#  3   cast          8797 non-null   object
#  4   country       8797 non-null   object
#  5   date_added    8797 non-null   datetime64[ns]
#  6   release_year  8797 non-null   int64
#  7   rating        8797 non-null   object
#  8   duration      8797 non-null   object
#  9   listed_in     8797 non-null   object
# dtypes: category(1), datetime64[ns](1), int64(1), object(7)
# memory usage: 696.0+ KB

# %%
print(rating_val)
# Out:
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# Unknown        4
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: rating, dtype: int64

# %%
df_opt[(df_opt['rating']=='74 min') | (df_opt['rating']=='84 min') | (df_opt['rating']=='66 min')]
# Out:
#        type                                 title    director        cast  \
# 5541  Movie                       Louis C.K. 2017  Louis C.K.  Louis C.K.
# 5794  Movie                 Louis C.K.: Hilarious  Louis C.K.  Louis C.K.
# 5813  Movie  Louis C.K.: Live at the Comedy Store  Louis C.K.  Louis C.K.
#
#             country date_added  release_year  rating duration listed_in
# 5541  United States 2017-04-04          2017  74 min  Unknown    Movies
# 5794  United States 2016-09-16          2010  84 min  Unknown    Movies
# 5813  United States 2016-08-15          2015  66 min  Unknown    Movies

# %%
df_opt.loc[(df_opt['rating']=='74 min') | 
            (df_opt['rating']=='84 min') | 
            (df_opt['rating']=='66 min'), 'duration'] = ['74 min', '84 min', '66 min']

# %%
df_opt.loc[(df_opt['rating']=='74 min') | 
            (df_opt['rating']=='84 min') | 
            (df_opt['rating']=='66 min'), 'rating'] = None

# %%
df_opt[(df_opt['date_added']== '2017-04-04')]
# Out:
#          type            title    director  \
# 5541    Movie  Louis C.K. 2017  Louis C.K.
# 6460  TV Show      Chewing Gum     Unknown
#
#                                                    cast         country  \
# 5541                                         Louis C.K.   United States
# 6460  Michaela Coel, John Macmillan, Robert Lonsdale...  United Kingdom
#
#      date_added  release_year rating   duration  \
# 5541 2017-04-04          2017   None     74 min
# 6460 2017-04-04          2017  TV-MA  2 Seasons
#
#                                               listed_in
# 5541                                             Movies
# 6460  British TV Shows, International TV Shows, Roma...

# %%
#df_opt[['duration_value','duration_unit']] = df_opt.duration.str.split(expand=True)
#df_opt.head()

# %%
#df_opt.drop(['duration'], inplace=True, axis=1)
#df_opt.head()

# %%
df_opt.to_csv(r'C:\Users\Syeda\Desktop\Data Analytics\Python Portfolio\Netflix\netflix_cleaned.csv')
